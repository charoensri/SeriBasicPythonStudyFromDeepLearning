# %%
# !adk create --type=code app_01 --model gemini-2.0-flash-live-001 --api_key $GEMINI_API_KEY
# Out:
# 'adk' is not recognized as an internal or external command,
# operable program or batch file.

# %%
"""After writing your agent, navigate to the "Running your agent" section in the notebook. Run the code cell and execute the following commands in the terminal (note that the lesson number and port number will be specific to each lesson, such as L1, L2, or 8001, 8002, etc.):"""
##cd L1
##adk web --host 0.0.0.0 --port 8001
# Out:
# 'After writing your agent, navigate to the "Running your agent" section in the notebook. Run the code cell and execute the following commands in the terminal (note that the lesson number and port number will be specific to each lesson, such as L1, L2, or 8001, 8002, etc.):'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# These commands move you to the correct directory where your agent directory sits and then launches the web browser interface where you can interact with your agent.

# %% [markdown]
# Step 3: Access the Testing Link
# Run the next cell in the notebook to generate your testing link. When you open the link, you should see the Agent Development Kit interface.
#
# In the top left corner, below the icon and "Agent Development Kit" title, verify that you see your app name (e.g., "app_01") - this confirms your agent folder was created correctly.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 4: Enable Your Microphone
# To begin testing your voice agent, click the microphone icon in the bottom right corner to activate it. Your browser may prompt you to grant microphone permissions:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Once enabled, you'll see a red microphone icon in the bottom right corner, indicating that your microphone is active and ready.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 5: Start Conversing
# Now you can start talking to your agent! Simply speak naturally - you'll hear the agent's responses through your speakers.
#
# Important Tips
# During Conversation:
#
# You only need to click the microphone icon once to activate it - no need to click repeatedly while talking
# The microphone stays active throughout your conversation, allowing for natural back-and-forth dialogue
# Ensure your browser has microphone permissions enabled
# Ending Your Session:
#
# When you're finished, simply close the browser tab

# %% [markdown]
# Step 6: Properly Close the ADK Web Process
# Before moving on to test other agents in subsequent lessons, it's crucial to properly terminate the current ADK web session. Run the following code cell (the very last one in the notebook):
#
# # Kill ADK process
# !pkill -f "adk web"
# Important: If you don't terminate the ADK web process, agents in other lessons may not work as expected. Always remember to run this command before proceeding to the next lesson.
